# %%
import matplotlib 
from matplotlib import pyplot as plt
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\user\Downloads\House_prediction.csv')
#print(len(df))
#df.shape
#pd.set_option("display.max.columns", None)
#pd.set_option("display.precision", 2)
#df.head
#df.head(3) to print first 3 rows of data set
#df.tail(3) to print last 3 rows of data set
# df.info print information about the data type of each column
#df.describe() shows basic statistics of the data set like mean std, min etc of every column

# %%
#print(df["city"].value_counts())
#df["area"].mean()
#df[['bathroom','city']].groupby("city").plot.bar()

# %%
#sum=df.groupby(["city"]).sum()
#count=df.groupby(["city"]).count()
#print(count)
#mean=sum/count
#print(mean)

# %%
#PART -1 STARTED

# %%
#city wise plotting of average rooms
val=df[['rooms','city']].groupby('city').mean().plot.bar()
print(val)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#city wise plotting of average rent amount
val2=df[['rent amount (R$)','city']].groupby('city').mean().plot.bar()
print(val2)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#city wise plotting of average number of bathrooms
val3=df[['bathroom','city']].groupby('city').mean().plot.bar()
print(val3)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#city wise plotting of average number of parking spaces
val4=df[['parking spaces','city']].groupby('city').mean().plot.bar()
print(val4)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#city wise plotting of average House association tax
val7=df[['hoa (R$)','city']].groupby('city').mean().plot.bar()
print(val7)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#city wise plotting of average value of property tax
val8=df[['property tax (R$)','city']].groupby('city').mean().plot.bar()
print(val8)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#city wise plotting of average total cost
finalavg=df[['total (R$)','city']].groupby('city').mean().plot.bar()
print(finalavg)
#part 1 ended
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#PART 1 ENDED 
#Part 2 started

# %%
#dependency of property tax on furnished or not furnished
deponrooms=df[['property tax (R$)','furniture']].groupby('furniture').mean().plot.bar()
print(deponrooms)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#dependency of house association tax on furnished or not furnished
houfur=df[['hoa (R$)','furniture']].groupby('furniture').mean().plot.bar()
print(houfur)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#dependency of fire insurance on furnished or not furnished
firfur=df[['fire insurance (R$)','furniture']].groupby('furniture').mean().plot.bar()
print(firfur)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#dependency of fire insurance on the number of rooms
firrooms=df[['fire insurance (R$)','rooms']].groupby('rooms').mean().plot.bar()
print(firfur)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#dependency of house association tax on the number of rooms
hourooms=df[['hoa (R$)','rooms']].groupby('rooms').mean().plot.bar()
print(hourooms)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#dependency of property tax on the number of rooms
proprooms=df[['property tax (R$)','rooms']].groupby('rooms').mean().plot.bar()
print(proprooms)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#Part 2 ENDED
